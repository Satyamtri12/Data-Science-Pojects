# %%
import pandas as pd

# %%
housing = pd.read_csv("mumbai_house_prices_500.csv")

# %%
housing.head()
# Out:
#    Area_sqft  Bedrooms  Bathrooms  Age_years  Distance_to_airport_km  \
# 0       1160         4          1         37                   16.17
# 1       1594         2          1          3                   17.96
# 2       1430         5          1         37                   18.18
# 3       1395         1          1         18                   23.39
# 4       1938         3          1          5                   33.29
#
#    Distance_to_metro_km  Distance_to_sea_km  Floor_number  \
# 0                  2.09               11.90            21
# 1                  0.11               22.68            11
# 2                  0.13               27.57            12
# 3                  0.66               28.54            10
# 4                  4.26               17.40            15
#
#    Neighborhood_score_1_10  Price_INR
# 0                        1   16708497
# 1                        9   47540709
# 2                       10   50139260
# 3                        6   34430465
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Area_sqft                500 non-null    int64
#  1   Bedrooms                 500 non-null    int64
#  2   Bathrooms                500 non-null    int64
#  3   Age_years                500 non-null    int64
#  4   Distance_to_airport_km   500 non-null    float64
#  5   Distance_to_metro_km     500 non-null    float64
#  6   Distance_to_sea_km       500 non-null    float64
#  7   Floor_number             500 non-null    int64
#  8   Neighborhood_score_1_10  500 non-null    int64
#  9   Price_INR                500 non-null    int64
# dtypes: float64(3), int64(7)
# memory usage: 39.2 KB

# %%
housing['Age_years'].value_counts()
# Out:
# Age_years
# 20    23
# 1     18
# 7     17
# 14    17
# 34    17
# 35    16
# 31    15
# 3     15
# 22    14
# 12    14
# 24    14
# 8     13
# 15    13
# 9     13
# 17    13
# 37    12
# 18    12
# 6     12
# 10    12
# 33    12
# 4     12
# 21    12
# 27    11
# 38    11
# 13    11
# 40    10
# 5     10
# 36    10
# 2     10
# 32    10
# 0     10
# 25    10
# 28    10
# 39    10
# 30    10
# 16    10
# 23     9
# 29     9
# 11     8
# 26     8
# 19     7
# Name: count, dtype: int64

# %%
housing.describe()
# Out:
#          Area_sqft    Bedrooms   Bathrooms   Age_years  \
# count   500.000000  500.000000  500.000000  500.000000
# mean   1425.630000    2.464000    1.494000   19.530000
# std     602.411255    0.977043    0.588776   11.822209
# min     301.000000    1.000000    1.000000    0.000000
# 25%     939.750000    2.000000    1.000000    9.000000
# 50%    1439.500000    2.000000    1.000000   20.000000
# 75%    1944.250000    3.000000    2.000000   30.000000
# max    2500.000000    5.000000    3.000000   40.000000
#
#        Distance_to_airport_km  Distance_to_metro_km  Distance_to_sea_km  \
# count              500.000000            500.000000          500.000000
# mean                20.069400              1.508120           15.050040
# std                  8.562719              1.515198            8.458774
# min                  5.050000              0.050000            0.200000
# 25%                 12.752500              0.467500            7.680000
# ...

# %%
#For` Plotting Histogram`
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Area_sqft'}>,
#         <Axes: title={'center': 'Bedrooms'}>,
#         <Axes: title={'center': 'Bathrooms'}>],
#        [<Axes: title={'center': 'Age_years'}>,
#         <Axes: title={'center': 'Distance_to_airport_km'}>,
#         <Axes: title={'center': 'Distance_to_metro_km'}>],
#        [<Axes: title={'center': 'Distance_to_sea_km'}>,
#         <Axes: title={'center': 'Floor_number'}>,
#         <Axes: title={'center': 'Neighborhood_score_1_10'}>],
#        [<Axes: title={'center': 'Price_INR'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# for learning purpose
import numpy as np


def split_train_test(data, test_ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    print(shuffled)
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(housing, 0.2)
# Out:
# [361  73 374 155 104 394 377 124  68 450   9 194 406  84 371 388 495  30
#  316 408 490 491 280 356  76 461 497 211 101 334 475 336 440 173   2 333
#  409  70 209  63 384  93 485 185  33  77   0  11 415  22  72 182 131 410
#  193  55 148  18 204  78 494 262 323 483  79  39 451  46 238 391 352 341
#  277 290 317 304 268  69 455 465 154  82 477 172 321  90 180 414 312 278
#  381 472 362 324 431 347  86  75 438  15 249 433  19 322 332  56 301 229
#  331 132 137 423 335  25 464 281 247 237 117  42 220 176 320 153 231 227
#  417 203 126 329  31 113 470 271 140  57 192  24  17 265  66 208 479  94
#  253 266  23 222 261 426   5 116  45  16 462 357   3 218 405  60 110 318
#  428  29 437 471  26   7 453 108  37 157 489 118 114 175 373 181 144 369
#  390 195 404 275 454 141 365  67 210 168 493 375 400 272 109 248 145  92
#  152 367 467  83 245 165 163 199 228  74 478 358 250 119 310 299 255 354
#  399 225 353 234 382 274  36 196 139 364 244 439 286  59 111  89 436   6
# ...

# %%
#print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 400
# Rows in test set: 100

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)
print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 400
# Rows in test set: 100

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(housing, housing['Age_years']):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# %%
strat_test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 414 to 22
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Area_sqft                100 non-null    int64
#  1   Bedrooms                 100 non-null    int64
#  2   Bathrooms                100 non-null    int64
#  3   Age_years                100 non-null    int64
#  4   Distance_to_airport_km   100 non-null    float64
#  5   Distance_to_metro_km     100 non-null    float64
#  6   Distance_to_sea_km       100 non-null    float64
#  7   Floor_number             100 non-null    int64
#  8   Neighborhood_score_1_10  100 non-null    int64
#  9   Price_INR                100 non-null    int64
# dtypes: float64(3), int64(7)
# memory usage: 8.6 KB

# %%
strat_test_set['Age_years'].value_counts()
# Out:
# Age_years
# 20    5
# 1     4
# 3     3
# 12    3
# 22    3
# 10    3
# 15    3
# 35    3
# 34    3
# 31    3
# 9     3
# 17    3
# 8     3
# 14    3
# 7     3
# 24    3
# 28    2
# 36    2
# 11    2
# 6     2
# 27    2
# 40    2
# 37    2
# 32    2
# 26    2
# 21    2
# 4     2
# 33    2
# 16    2
# 29    2
# 23    2
# 13    2
# 38    2
# 0     2
# 2     2
# 5     2
# 25    2
# 18    2
# 30    2
# 39    2
# 19    1
# Name: count, dtype: int64

# %%
strat_train_set['Age_years'].value_counts()
# Out:
# Age_years
# 20    18
# 14    14
# 34    14
# 7     14
# 1     14
# 35    13
# 3     12
# 31    12
# 22    11
# 12    11
# 24    11
# 18    10
# 37    10
# 15    10
# 8     10
# 17    10
# 4     10
# 9     10
# 33    10
# 6     10
# 21    10
# 38     9
# 13     9
# 27     9
# 10     9
# 30     8
# 40     8
# 25     8
# 16     8
# 0      8
# 28     8
# 39     8
# 32     8
# 5      8
# 36     8
# 2      8
# 23     7
# 29     7
# 26     6
# 11     6
# 19     6
# Name: count, dtype: int64

# %% [markdown]
# ## Looking for correlation

# %%
corr_matrix = housing.corr()

# %%
corr_matrix['Price_INR'].sort_values(ascending=False)
# Out:
# Price_INR                  1.000000
# Area_sqft                  0.846707
# Neighborhood_score_1_10    0.452384
# Bathrooms                  0.033767
# Bedrooms                   0.013686
# Floor_number               0.010505
# Distance_to_airport_km    -0.076395
# Distance_to_metro_km      -0.110676
# Distance_to_sea_km        -0.121549
# Age_years                 -0.133012
# Name: Price_INR, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ["Price_INR", "Area_sqft", "Bedrooms", "Bathrooms"]
scatter_matrix(housing[attributes], figsize=(12, 8))
# Out:
# array([[<Axes: xlabel='Price_INR', ylabel='Price_INR'>,
#         <Axes: xlabel='Area_sqft', ylabel='Price_INR'>,
#         <Axes: xlabel='Bedrooms', ylabel='Price_INR'>,
#         <Axes: xlabel='Bathrooms', ylabel='Price_INR'>],
#        [<Axes: xlabel='Price_INR', ylabel='Area_sqft'>,
#         <Axes: xlabel='Area_sqft', ylabel='Area_sqft'>,
#         <Axes: xlabel='Bedrooms', ylabel='Area_sqft'>,
#         <Axes: xlabel='Bathrooms', ylabel='Area_sqft'>],
#        [<Axes: xlabel='Price_INR', ylabel='Bedrooms'>,
#         <Axes: xlabel='Area_sqft', ylabel='Bedrooms'>,
#         <Axes: xlabel='Bedrooms', ylabel='Bedrooms'>,
#         <Axes: xlabel='Bathrooms', ylabel='Bedrooms'>],
#        [<Axes: xlabel='Price_INR', ylabel='Bathrooms'>,
#         <Axes: xlabel='Area_sqft', ylabel='Bathrooms'>,
#         <Axes: xlabel='Bedrooms', ylabel='Bathrooms'>,
#         <Axes: xlabel='Bathrooms', ylabel='Bathrooms'>]], dtype=object)

# %%
housing.plot(kind="scatter", x="Area_sqft", y="Price_INR", alpha=0.8)
# Out:
# <Axes: xlabel='Area_sqft', ylabel='Price_INR'>

# %% [markdown]
# ## Trying out Attributes combination

# %%
housing["TAXRM"] = housing['Area_sqft']/housing['Bedrooms']

# %%
housing["TAXRM"]
# Out:
# 0       290.000000
# 1       797.000000
# 2       286.000000
# 3      1395.000000
# 4       646.000000
#           ...
# 495     144.333333
# 496    1202.500000
# 497     328.000000
# 498     538.000000
# 499     371.333333
# Name: TAXRM, Length: 500, dtype: float64

# %%
housing.head()
# Out:
#    Area_sqft  Bedrooms  Bathrooms  Age_years  Distance_to_airport_km  \
# 0       1160         4          1         37                   16.17
# 1       1594         2          1          3                   17.96
# 2       1430         5          1         37                   18.18
# 3       1395         1          1         18                   23.39
# 4       1938         3          1          5                   33.29
#
#    Distance_to_metro_km  Distance_to_sea_km  Floor_number  \
# 0                  2.09               11.90            21
# 1                  0.11               22.68            11
# 2                  0.13               27.57            12
# 3                  0.66               28.54            10
# 4                  4.26               17.40            15
#
#    Neighborhood_score_1_10  Price_INR   TAXRM
# 0                        1   16708497   290.0
# 1                        9   47540709   797.0
# 2                       10   50139260   286.0
# ...
